# %%
import dlc_practical_prologue as prologue


from models import *
from trainings import *
from utils import *

train_input, train_target, train_classes, test_input, test_target, test_classes = [x.cuda() for x in prologue.generate_pair_sets(1000)]
model=ConvNetAux(10).cuda()
_ =all_training(model, train_input, train_target, train_classes, test_input, test_target, test_classes, betas=[0.3, 0.4], nb_epochs=[50], mini_batch_sizes=[100], lrs=[1e-3])
# Out:
# Computing with: mini batch size = 100
#                 learning rate = 0.001
#                 number of epoch = 50
#                 beta = 0.3
# Final error train digit: 10.85
# Final error train comparison: 12.40
# Final error test digit: 7.50
# Final error test comparison: 13.40
#
#
# Computing with: mini batch size = 100
#                 learning rate = 0.001
#                 number of epoch = 50
#                 beta = 0.4
# Final error train digit: 12.20
# Final error train comparison: 13.50
# Final error test digit: 10.05
# Final error test comparison: 11.50
